# %% [markdown]
# #  Assignment - 2 (Data Visualization)

# %% [markdown]
# ## Sai Ram Amajala

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
import seaborn as sns

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
sns.__version__
# Out:
# '0.12.2'

# %%
df = pd.read_csv('D:\car_crashes.csv', encoding='windows-1252')

# %%
df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %%
df.tail(4)
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 47   10.6     4.452    3.498           8.692        9.116       890.03
# 48   23.8     8.092    6.664          23.086       20.706       992.61
# 49   13.8     4.968    4.554           5.382       11.592       670.31
# 50   17.4     7.308    5.568          14.094       15.660       791.14
#
#     ins_losses abbrev
# 47      111.62     WA
# 48      152.56     WV
# 49      106.62     WI
# 50      122.04     WY

# %% [markdown]
# ## Line Plot

# %%
sns.lineplot(x="total",y="alcohol",data=df,ci=None)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11496\2580749017.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x="total",y="alcohol",data=df,ci=None)
# <Axes: xlabel='total', ylabel='alcohol'>

# %%
## Inference:From the plot we can say that as total increases,the alcohol consumption also increases

# %% [markdown]
# ## Scatter Plot

# %%
sns.scatterplot(x="total",y="speeding",data=df)
# Out:
# <Axes: xlabel='total', ylabel='speeding'>

# %%
## Inference:From the plot we can say that as total increases,the speeding also increases

# %% [markdown]
# ## Box plot

# %%
sns.boxplot(x="total",y="alcohol",data=df)
# Out:
# <Axes: xlabel='total', ylabel='alcohol'>

# %% [markdown]
# ## Dist plot

# %%
sns.distplot(df["total"])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11496\1102674835.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["total"])
# <Axes: xlabel='total', ylabel='Density'>

# %%
## Inference:The plot shows the distribution of the differences between total and Density

# %%
sns.distplot(df["alcohol"])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11496\3201832786.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["alcohol"])
# <Axes: xlabel='alcohol', ylabel='Density'>

# %%
## Inference:The plot shows the distribution of the differences between alcohol and Density

# %% [markdown]
# ## Re plot

# %%
sns.relplot(x="total",y="no_previous",data=df)

# %%
## Inference:From the plot we can say that as total increases,no_previous also increases

# %% [markdown]
# ## Bar plot

# %%
sns.barplot(data=df,x="not_distracted",y="no_previous",ci=None)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11496\414535629.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df,x="not_distracted",y="no_previous",ci=None)
# <Axes: xlabel='not_distracted', ylabel='no_previous'>

# %%
## Inference:From the plot we can say that as not_distracted increases,the no_previous also increases

# %% [markdown]
# ## Joint plot

# %%
sns.jointplot(x="total",y="ins_losses",data=df)

# %%
## Inference:The plot shows the distribution of the differences between total and ins_losses

# %% [markdown]
# ## Violin plot

# %%
sns.violinplot(df['alcohol'])
# Out:
# <Axes: >

# %%
## Inference:The plot shows the distribution of the alcohol

# %% [markdown]
# ## Swarm plot

# %%
sns.swarmplot(x = df["speeding"])
# Out:
# <Axes: xlabel='speeding'>

# %%
## Inference:The plot shows the distribution of speeding

# %% [markdown]
# ## Point plot

# %%
sns.pointplot(x = "speeding", y = "alcohol", data = df)
# Out:
# <Axes: xlabel='speeding', ylabel='alcohol'>

# %%
## Inference:The plot shows the distribution of the differences between speeding and alcohol

# %%
sns.pointplot(x = "speeding", y = "alcohol", data = df, join = False)
# Out:
# <Axes: xlabel='speeding', ylabel='alcohol'>

# %%
## Inference:The plot shows the distribution of the differences between speeding and alcohol
